# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-ep6pwsab because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
from visuals import *
from utils import *
from model import *
from dataset import *
from data_module import *

# %%
plt.rcParams['figure.figsize'] = (14,10)
font = {'family' : 'DejaVu Sans',  'weight' : 'normal',  'size'  : 22}
plt.rc('font', **font)

# %%
df = pd.read_csv('dataset_strat.csv')

# %%
df["bboxes"] = df["bboxes"].apply(eval) # DONT forget this cell

# %%
#dm = BoltDataModule(df, num_workers = 16, bs = 2)

# %%
model = BoltDetector(df, bs=3, num_classes=1, img_size=1024)
# Out:
# {'name': 'tf_efficientnetv2_l', 'backbone_name': 'tf_efficientnetv2_l', 'backbone_args': {'drop_path_rate': 0.2}, 'backbone_indices': None, 'image_size': [1024, 1024], 'num_classes': 1, 'min_level': 3, 'max_level': 7, 'num_levels': 5, 'num_scales': 3, 'aspect_ratios': [[1.0, 1.0], [1.4, 0.7], [0.7, 1.4]], 'anchor_scale': 4.0, 'pad_type': 'same', 'act_type': 'swish', 'norm_layer': None, 'norm_kwargs': {'eps': 0.001, 'momentum': 0.01}, 'box_class_repeats': 3, 'fpn_cell_repeats': 3, 'fpn_channels': 88, 'separable_conv': True, 'apply_resample_bn': True, 'conv_bn_relu_pattern': False, 'downsample_type': 'max', 'upsample_type': 'nearest', 'redundant_bias': True, 'head_bn_level_first': False, 'head_act_type': None, 'fpn_name': None, 'fpn_config': None, 'fpn_drop_path_rate': 0.0, 'alpha': 0.25, 'gamma': 1.5, 'label_smoothing': 0.0, 'legacy_focal': False, 'jit_loss': False, 'delta': 0.1, 'box_loss_weight': 50.0, 'soft_nms': False, 'max_detection_points': 5000, 'max_det_per_image': 100, 'url': ''}
# backbone True
# fpn True
# class_net True
# box_net True
# 108
# 36
# 35

# %%
#path = '/media/scratch/astamoulakatos/NMIS/detector/detector-epoch=83-valid_loss=0.57.ckpt'
import os

for root, dirs, files in os.walk("./detector", topdown=False):
  for name in files:
    path= os.path.join(os.getcwd(), "detector", name)
    break

print(path)
# Out:
# /home/jovyan/work/COREF/src/Bolt_Detection/detector/epoch=8-valid_loss=1.46.ckpt

# %%
model = model.load_from_checkpoint(path, map_location='cuda:0')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 model = model.load_from_checkpoint(path, map_location='cuda:0')
#
# File /opt/conda/lib/python3.9/site-packages/pytorch_lightning/core/saving.py:137, in ModelIO.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#     135 with pl_legacy_patch():
#     136     if map_location is not None:
# --> 137         checkpoint = pl_load(checkpoint_path, map_location=map_location)
#     138     else:
#     139         checkpoint = pl_load(checkpoint_path, map_location=lambda storage, loc: storage)
#
# File /opt/conda/lib/python3.9/site-packages/pytorch_lightning/utilities/cloud_io.py:47, in load(path_or_url, map_location)
#      45 fs = get_filesystem(path_or_url)
#      46 with fs.open(path_or_url, "rb") as f:
# ---> 47     return torch.load(f, map_location=map_location)
#
# File /opt/conda/lib/python3.9/site-packages/torch/serialization.py:712, in load(f, map_location, pickle_module, **pickle_load_args)
#     710             opened_file.seek(orig_position)
#     711             return torch.jit.load(opened_file)
# --> 712         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     713 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File /opt/conda/lib/python3.9/site-packages/torch/serialization.py:1046, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#    1044 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1045 unpickler.persistent_load = persistent_load
# -> 1046 result = unpickler.load()
#    1048 torch._utils._validate_loaded_sparse_tensors()
#    1050 return result
#
# File /opt/conda/lib/python3.9/site-packages/torch/serialization.py:1016, in _load.<locals>.persistent_load(saved_id)
#    1014 if key not in loaded_storages:
#    1015     nbytes = numel * torch._utils._element_size(dtype)
# -> 1016     load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1018 return loaded_storages[key]
#
# File /opt/conda/lib/python3.9/site-packages/torch/serialization.py:1001, in _load.<locals>.load_tensor(dtype, numel, key, location)
#     997 storage = zip_file.get_storage_from_record(name, numel, torch._UntypedStorage).storage()._untyped()
#     998 # TODO: Once we decide to break serialization FC, we can
#     999 # stop wrapping with _TypedStorage
#    1000 loaded_storages[key] = torch.storage._TypedStorage(
# -> 1001     wrap_storage=restore_location(storage, location),
#    1002     dtype=dtype)
#
# File /opt/conda/lib/python3.9/site-packages/torch/serialization.py:970, in _get_restore_location.<locals>.restore_location(storage, location)
#     969 def restore_location(storage, location):
# --> 970     return default_restore_location(storage, map_location)
#
# File /opt/conda/lib/python3.9/site-packages/torch/serialization.py:176, in default_restore_location(storage, location)
#     174 def default_restore_location(storage, location):
#     175     for _, _, fn in _package_registry:
# --> 176         result = fn(storage, location)
#     177         if result is not None:
#     178             return result
#
# File /opt/conda/lib/python3.9/site-packages/torch/serialization.py:158, in _cuda_deserialize(obj, location)
#     156         return storage_type(obj.nbytes())
#     157 else:
# --> 158     return obj.cuda(device)
#
# File /opt/conda/lib/python3.9/site-packages/torch/_utils.py:79, in _cuda(self, device, non_blocking, **kwargs)
#      77 else:
#      78     new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 79     return new_type(self.size()).copy_(self, non_blocking)
#
# File /opt/conda/lib/python3.9/site-packages/torch/cuda/__init__.py:661, in _lazy_new(cls, *args, **kwargs)
#     658 _lazy_init()
#     659 # We may need to call lazy init again if we are a forked child
#     660 # del _CudaBase.__new__
# --> 661 return super(_CudaBase, cls).__new__(cls, *args, **kwargs)
#
# RuntimeError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.

# %%
model.eval();

# %%
for i in range(len(model.valid_dataset)):
    img = model.valid_dataset[i][0]
    bolts = model.valid_dataset[i][2]
    model.count_bolts(img.unsqueeze(0), bolts)
# Out:
# Ground Truth Bolts = 7
# Predicted Bolts Count = 7
# Ground Truth Bolts = 7
# Predicted Bolts Count = 7
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 6
# Predicted Bolts Count = 6
# Ground Truth Bolts = 7
# Predicted Bolts Count = 7
# Ground Truth Bolts = 11
# Predicted Bolts Count = 5
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 7
# Predicted Bolts Count = 7
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 9
# Predicted Bolts Count = 0
# Ground Truth Bolts = 10
# Predicted Bolts Count = 10
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 11
# Predicted Bolts Count = 11
# Ground Truth Bolts = 1
# Predicted Bolts Count = 2
# Ground Truth Bolts = 10
# Predicted Bolts Count = 1
# Ground Truth Bolts = 11
# Predicted Bolts Count = 11
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 8
# Predicted Bolts Count = 8
# Ground Truth Bolts = 11
# Predicted Bolts Count = 11
# Ground Truth Bolts = 2
# Predicted Bolts Count = 2
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 2
# Predicted Bolts Count = 2
# Ground Truth Bolts = 2
# Predicted Bolts Count = 2
# Ground Truth Bolts = 9
# Predicted Bolts Count = 9
# Ground Truth Bolts = 9
# Predicted Bolts Count = 9
# Ground Truth Bolts = 8
# Predicted Bolts Count = 0
# Ground Truth Bolts = 5
# Predicted Bolts Count = 5
# Ground Truth Bolts = 2
# Predicted Bolts Count = 2
# Ground Truth Bolts = 4
# Predicted Bolts Count = 4
# Ground Truth Bolts = 5
# Predicted Bolts Count = 1
# Ground Truth Bolts = 3
# Predicted Bolts Count = 3
# Ground Truth Bolts = 3
# Predicted Bolts Count = 3

# %%
for i in range(len(model.test_dataset)):
    img = model.test_dataset[i][0]
    bolts = model.test_dataset[i][2]
    model.count_bolts(img.unsqueeze(0), bolts)
# Out:
# Ground Truth Bolts = 7
# Predicted Bolts Count = 7
# Ground Truth Bolts = 7
# Predicted Bolts Count = 4
# Ground Truth Bolts = 10
# Predicted Bolts Count = 10
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 11
# Predicted Bolts Count = 2
# Ground Truth Bolts = 6
# Predicted Bolts Count = 6
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 4
# Predicted Bolts Count = 4
# Ground Truth Bolts = 7
# Predicted Bolts Count = 7
# Ground Truth Bolts = 7
# Predicted Bolts Count = 7
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 5
# Predicted Bolts Count = 5
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 8
# Predicted Bolts Count = 8
# Ground Truth Bolts = 11
# Predicted Bolts Count = 11
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 2
# Predicted Bolts Count = 2
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 9
# Predicted Bolts Count = 1
# Ground Truth Bolts = 5
# Predicted Bolts Count = 5
# Ground Truth Bolts = 2
# Predicted Bolts Count = 2
# Ground Truth Bolts = 1
# Predicted Bolts Count = 1
# Ground Truth Bolts = 2
# Predicted Bolts Count = 3
# Ground Truth Bolts = 3
# Predicted Bolts Count = 3
# Ground Truth Bolts = 9
# Predicted Bolts Count = 9
# Ground Truth Bolts = 11
# Predicted Bolts Count = 11
# Ground Truth Bolts = 2
# Predicted Bolts Count = 2
# Ground Truth Bolts = 9
# Predicted Bolts Count = 9
# Ground Truth Bolts = 11
# Predicted Bolts Count = 4
# Ground Truth Bolts = 3
# Predicted Bolts Count = 3
# Ground Truth Bolts = 10
# Predicted Bolts Count = 5
